# %% [markdown]
# # Importando as Bibliotecas e os Dados

# %%
import geopandas as gpd
import pandas as pd
from utils import import_data
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import seaborn.objects as so

# %%
data_dict = import_data()

data_dict.keys()
# Out:
# dict_keys(['Customers', 'Geolocation', 'Order_Items', 'Order_Payments', 'Order_Reviews', 'Orders', 'Products', 'Sellers'])

# %% [markdown]
# Vou dar umas visualizada nos dados para compreende-los melhor

# %%
for keys, value in data_dict.items():
    print(keys)
    display(value.head())
# Out:
# Customers
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# Geolocation
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# ...

# %% [markdown]
# # Análise Exploratória de Dados

# %% [markdown]
# ## Compradores e Vendedores

# %% [markdown]
# Meu objetivo é compreender quem demanda e quem oferta os produtos da plataforma. Para tal, quero onde estes moram e quais os principais produtos que estes comercializam

# %% [markdown]
# ### Localização

# %%
def plot_brazilian_maps(state_column_name: str, data: pd.DataFrame, brazil_map: gpd.GeoDataFrame = None, return_br_gpd: bool = False):
    
    if brazil_map is None:
        brazil_map = gpd.read_file(
            filename= "https://geoftp.ibge.gov.br/cartas_e_mapas/bases_cartograficas_continuas/bcim/versao2016/geopackage/bcim_2016_21_11_2018.gpkg",
            layer = 'lim_unidade_federacao_a'
        )

    data = data[state_column_name].value_counts().reset_index(name='count')
    
    df = pd.merge(
        left=brazil_map,
        right=data,
        left_on='sigla',
        right_on='index',
        how='left'
    )
    
    if return_br_gpd:
        return (
            df.plot(column='count', cmap='OrRd', figsize=(20, 10), legend=True),
            brazil_map
        )
    else:
        return df.plot(column='count', cmap='OrRd', figsize=(20, 10), legend=True)

# %%
data_dict['Customers'].head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
plot_brazilian_maps(
    state_column_name='customer_state',
    data=data_dict['Customers']
)
# Out:
# <Axes: >

# %%
data_dict['Sellers'].head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
plot_brazilian_maps(
    state_column_name='seller_state',
    data=data_dict['Sellers']
)
# Out:
# <Axes: >

# %%
p = (
    so.Plot(
        data = pd.concat([
            (
                data_dict['Sellers']
                .seller_state
                .value_counts(normalize=True)
                .reset_index()
                .assign(Tipo = 'Vendedores')
                .rename(columns={'index': 'Estado', 'seller_state': 'Porcentagem'})
            ),
            (
                data_dict['Customers']
                .customer_state
                .value_counts(normalize=True)
                .reset_index()
                .assign(Tipo = 'Consumidores')
                .rename(columns={'index': 'Estado', 'customer_state' : 'Porcentagem'})
            )
        ]).reset_index(drop=True),
        x='Estado',
        y='Porcentagem',
        color='Tipo'
        
    )
    .layout(size=(10, 8))
    .add(so.Bar(), so.Dodge())
)

p.show()

# %% [markdown]
# #### Conclusão
#
# De acordo com os dois mapas acima, podemos perceber que a maioria dos clientes e vendedores estão localizados no estado de São Paulo. No entanto, o estado de Minas Gerais e Rio De Janeiro também possui uma quantidade significativa de clientes e vendedores. Vale ressaltar a diferença entre consumidores e vendedores, onde enquanto o primeiro é melhor distribuido em todo o país, o segundo possui uma maior concentração no sudeste, principalmente me São Paulo. Os estado São Paulo, Paraná e Santa Catarina produzem mais produtos do que consomem, enquanto o resto consome mais do que produz.

# %% [markdown]
# ### Produtos

# %%
data_dict['Orders'].head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_purchase_to_approved_time order_delivered_carrier_date  \
# 0                 0 days 00:10:42          2017-10-04 19:55:00
# ...

# %%
data_dict['Products'].head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
data_dict['Order_Items'].head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  total_cost
# 0 2017-09-19 09:45:35   58.90          13.29       72.19
# 1 2017-05-03 11:05:13  239.90          19.93      259.83
# 2 2018-01-18 14:48:30  199.00          17.87      216.87
# ...

# %%
join_order_items_and_products = pd.merge(
    right=data_dict['Order_Items'],
    left=data_dict['Products'],
    how='left',
    on='product_id'
)[[
    'product_category_name',
    'price',
    'freight_value',
    'total_cost'
]]

join_order_items_and_products.head()
# Out:
#    product_category_name   price  freight_value  total_cost
# 0             perfumaria   10.91           7.39       18.30
# 1                  artes  248.00          17.99      265.99
# 2          esporte_lazer   79.80           7.82       87.62
# 3                  bebes  112.30           9.54      121.84
# 4  utilidades_domesticas   37.90           8.29       46.19

# %%
def plot_kde(percentile: list[float,float], column: str, data: pd.DataFrame):
    lower = np.percentile(data[column], (percentile[0] * 100))
    higher = np.percentile(data[column], (percentile[1] * 100))
    
    print(higher, lower)
    return sns.kdeplot(
        data=data,
        x=column,
        clip=(lower, higher)
    )

# %%
plot_kde(percentile=[.02, .98], column='price', data=join_order_items_and_products)
# Out:
# 619.0 12.9
# <Axes: xlabel='price', ylabel='Density'>

# %%
plot_kde(percentile=[.02, .98], column='total_cost', data=join_order_items_and_products)
# Out:
# 668.04 24.06
# <Axes: xlabel='total_cost', ylabel='Density'>

# %%
plot_kde(percentile=[.1, .99], column='freight_value', data=join_order_items_and_products)
# Out:
# 84.52 8.73
# <Axes: xlabel='freight_value', ylabel='Density'>

# %%
join_order_items_and_products.total_cost.describe().to_frame().T[['mean', 'std', 'min', '25%', '50%', '75%', 'max']].rename(columns={"50%" : "Mediana", "mean" : 'Media', 'std' : 'Desvio Padrão', 'max' : 'Max', 'min' : 'Min'})
# Out:
#                  Media  Desvio Padrão   Min    25%  Mediana       75%      Max
# total_cost  140.644059     190.724394  6.08  55.22    92.32  157.9375  6929.31

# %% [markdown]
# O ticket médio dos produtos é de R$ 120,00. No entanto, como podemos observar nos gráficos e na tabela acima, existe uma grande quantidade de outliers que estão distorcendo a distribuição dos dados. Em uma pequena quantidade dos casos, os produtos foram vendidos por valores muito acima do normal

# %% [markdown]
# Podemos sumarizar, portanto, que a ordem média é por volta de R$ 75,00 e sendo produzida e destinada ao eixo centro-sul do país.

# %% [markdown]
# #### Produtos mais vendidos

# %%
(
    so.Plot(
        data=(join_order_items_and_products.product_category_name.value_counts(normalize=True) * 100).head(10).reset_index(),
        y = 'index',
        x = 'product_category_name'
    )
    .add(so.Bar(), so.Dodge())
    .layout(size=(15, 8))
    .label(x='Porcentagem do Volume Total', y='Produtos')
)

# %% [markdown]
# A tabela acima nos mostra os produtos mais vendidos e suas respectivas proporções em relação ao volume total de comércio.

# %% [markdown]
# Qual será a nota média dos produtos mais perdidos ?

# %%
(
    pd.merge(
        right=data_dict['Order_Items'],
        left=data_dict['Products'],
        how='left',
        on='product_id')
    .merge(
        right=(join_order_items_and_products.product_category_name.value_counts(normalize=True) * 100).head(10).reset_index(),
        left_on='product_category_name',
        right_on='index',
    ).merge(
        right=data_dict['Order_Reviews'],
        on='order_id'
    )
    [[
        'product_category_name_x',
        'review_score'
    ]]
    .groupby(['product_category_name_x'])
    .mean()
    .reset_index()
    .assign(review_score = lambda x: round(x.review_score, 2),
            product_category_name_x = lambda x: x.product_category_name_x.str.replace("_", " "))
    .rename(columns={
        "product_category_name_x" : "Produto",
        "review_score" : "Avaliação"
    })
)
# Out:
#                   Produto  Avaliação
# 0              automotivo       4.07
# 1            beleza saude       4.14
# 2         cama mesa banho       3.90
# 3           esporte lazer       4.11
# 4      ferramentas jardim       4.04
# 5  informatica acessorios       3.93
# 6        moveis decoracao       3.90
# 7      relogios presentes       4.02
# 8               telefonia       3.95
# 9   utilidades domesticas       4.06

# %% [markdown]
# Pelo jeito, todos os produtos mais vendidos tem uma nota média perto de 4. Não há nenhuma grande diferença entre estes.

# %% [markdown]
# ## Tipos de pagamento

# %% [markdown]
# Agora procuramos entender como os clientes efetuam o pagamento das compras

# %%
data_dict['Order_Payments'].head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
(
    so.Plot(
        data = (data_dict['Order_Payments'].payment_type.value_counts(normalize=True) * 100).reset_index(),
        x = 'index',
        y = 'payment_type'
    )
    .add(so.Bar())
    .layout(size=(15, 8))
)

# %% [markdown]
# De acordo com o gráfico acima, a maioria dos clientes efetuam o pagamento com cartão de crédito. Em segundo lugar, temos o pagamento com boleto bancário.

# %%
(data_dict['Order_Payments'].payment_installments.value_counts(normalize=True) * 100).reset_index().rename(columns={'index' : 'payment_installments', 'payment_installments' : 'Perc_total'}).assign(Perc_total = lambda x: round(x.Perc_total, 2)).head(10)
# Out:
#    payment_installments  Perc_total
# 0                     1       50.58
# 1                     2       11.95
# 2                     3       10.07
# 3                     4        6.83
# 4                    10        5.13
# 5                     5        5.04
# 6                     8        4.11
# 7                     6        3.77
# 8                     7        1.57
# 9                     9        0.62

# %%
(data_dict['Order_Payments'].query("payment_installments > 1").payment_installments.value_counts(normalize=True) * 100).reset_index().rename(columns={'index' : 'payment_installments', 'payment_installments' : 'Perc_total'})
# Out:
#     payment_installments  Perc_total
# 0                      2   24.178971
# 1                      3   20.376719
# 2                      4   13.826016
# 3                     10   10.378277
# 4                      5   10.204916
# 5                      8    8.313530
# 6                      6    7.635669
# 7                      7    3.167245
# 8                      9    1.254431
# 9                     12    0.259067
# 10                    15    0.144143
# 11                    18    0.052593
# 12                    11    0.044801
# 13                    24    0.035062
# 14                    20    0.033114
# 15                    13    0.031166
# 16                    14    0.029218
# 17                    17    0.015583
# 18                    16    0.009739
# 19                    21    0.005844
# 20                    22    0.001948
# 21                    23    0.001948

# %% [markdown]
# Pelo jeito, um pouco mais que a metade dos produtos são vendidos a vista, enquanto o restante é parcelado em alguma modalidade. O padrão observado entre os parcelados é que é preferível uma parcela menor que uma menor quantidade de parcelas.
